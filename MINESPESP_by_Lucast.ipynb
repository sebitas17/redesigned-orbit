# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2f0TawtBRGfAsA09GrQPl2yI4in_6ja6up6j3BKLF6FMXpTKX" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar	    ops.json	       usercache.json
# banned-players.json  forge.jar.log  permissions.yml    usernamecache.json
# bukkit.yml	     help.yml	    plugins	       whitelist.json
# colabconfig.json     libraries	    run.bat	       world
# commands.yml	     logs	    run.sh	       xaerominimap-common.txt
# config		     mods	    server.properties  xaeroworldmap-common.txt
# defaultconfigs	     mohist-config  spigot.yml
# eula.txt	     mohist.jar     user_jvm_args.txt
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:14636
# Estas jugando a minecraft: mohist en su version: 1.20.1
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 23144
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-664 but you have 1.20.1-580. The latest version has been built on 2024-04-12 15:42:29. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [15:52:42 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [15:52:42 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [15:52:42 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [15:52:42 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [15:52:43 WARN]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [15:52:43 INFO]: Found 4 dependencies adding them to mods collection
# [15:52:45 INFO]: Compatibility level set to JAVA_17
# [15:52:45 ERROR]: Mixin config okzoomer.mixins.json does not specify "minVersion" property
# [15:52:45 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [15:52:45 WARN]: Reference map 'trashslot.refmap.json' for trashslot.mixins.json could not be read. If this is a development environment you can ignore this message
# [15:52:45 INFO]: Loaded configuration file for Embeddium: 87 options available, 0 override(s) found
# [15:52:45 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [15:52:47 WARN]: Error loading class: noobanidus/mods/lootr/config/ConfigManager (java.lang.ClassNotFoundException: noobanidus.mods.lootr.config.ConfigManager)
# [15:52:47 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.2).
# [Mouse Tweaks] Disabled because not running on the client.
# [15:52:54 INFO]: Registering C2S receiver with id architectury:sync_ids
# [15:52:54 INFO]: Registering C2S receiver with id artifacts:networking_channel/42a7ad70b1cc371599a0eff744096b8a
# [15:52:54 INFO]: Registering C2S receiver with id artifacts:networking_channel/74a5e841822a3a87854ae896a33430d6
# [15:52:54 INFO]: Registering C2S receiver with id artifacts:networking_channel/eb3d1e2748533430848cadf0f37c7e9c
# [15:52:54 INFO]: Registering C2S receiver with id artifacts:networking_channel/91c8520f19f93b3e8b6a727568e194ab
# [15:52:54 INFO]: Registering C2S receiver with id artifacts:networking_channel/8c2784d778293fd482ed84b8aa5fedb9
# [15:52:55 INFO]: Mohist mod loading.....
# [15:52:55 INFO]: EventDispatcherRegistry initialized
# [15:52:55 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [15:52:55 INFO]: MinecraftForge v47.2.20 Initialized
# [15:52:55 INFO]: NeoForge v47.2.20 Initialized
# [15:52:55 INFO]: ExpandAbility here, who dis?
# [15:52:55 ERROR]: Attempted to load class net/minecraft/client/Minecraft for invalid dist DEDICATED_SERVER
# [15:52:55 ERROR]: Failed to update fingerprint
# java.lang.NoClassDefFoundError: net/minecraft/client/Minecraft
# 	at me.jellysquid.mods.sodium.client.data.fingerprint.FingerprintMeasure.create(FingerprintMeasure.java:19) ~[embeddium-0.3.4+mc1.20.1.jar%23242!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.updateFingerprint(SodiumClientMod.java:104) ~[embeddium-0.3.4+mc1.20.1.jar%23242!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.<init>(SodiumClientMod.java:45) ~[embeddium-0.3.4+mc1.20.1.jar%23242!/:?]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:76) ~[javafmllanguage-1.20.1-47.2.20.jar%23266!/:?]
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$10(ModContainer.java:123) ~[fmlcore-1.20.1-47.2.20.jar%23265!/:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# Caused by: java.lang.ClassNotFoundException: net.minecraft.client.Minecraft
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	... 15 more
# [15:52:55 INFO]: Discovered 160 modules to load.
# [15:52:55 INFO]: Constructing module Abacus...
# [15:52:55 INFO]: Constructing module Adjustable Chat...
# [15:52:55 INFO]: Constructing module Ambient Discs...
# [15:52:55 INFO]: Constructing module Ancient Tomes...
# [15:52:55 INFO]: Constructing module Ancient Wood...
# [15:52:55 INFO]: Constructing module Armed Armor Stands...
# [15:52:55 INFO]: Constructing module Auto Walk Keybind...
# [15:52:55 INFO]: Constructing module Automatic Recipe Unlock...
# [15:52:55 INFO]: Constructing module Automatic Tool Restock...
# [15:52:55 INFO]: Constructing module Azalea Wood...
# [15:52:55 INFO]: Constructing module Back Button Keybind...
# [15:52:55 INFO]: Constructing module Backpack...
# [15:52:55 INFO]: Constructing module Beacon Redirection...
# [15:52:55 INFO]: Constructing module Better Elytra Rocket...
# [15:52:55 INFO]: Constructing module Big Stone Clusters...
# [15:52:55 INFO]: Constructing module Blossom Trees...
# [15:52:55 INFO]: Constructing module Bottled Cloud...
# [15:52:55 INFO]: Constructing module Buckets Show Inhabitants...
# [15:52:55 INFO]: Constructing module Camera...
# [15:52:55 INFO]: Constructing module Campfires Boost Elytra...
# [15:52:55 INFO]: Constructing module Celebratory Lamps...
# [15:52:55 INFO]: Constructing module Chains Connect Blocks...
# [15:52:55 INFO]: Constructing module Chest Searching...
# [15:52:55 INFO]: Constructing module Chorus Vegetation...
# [15:52:55 INFO]: Constructing module Chute...
# [15:52:55 INFO]: Constructing module Climate Control Remover...
# [15:52:55 INFO]: Constructing module Color Runes...
# [15:52:55 INFO]: Constructing module Compasses Work Everywhere...
# [15:52:55 INFO]: Constructing module Compressed Blocks...
# [15:52:55 INFO]: Constructing module Coral On Cactus...
# [15:52:55 INFO]: Constructing module Corundum...
# [15:52:55 INFO]: Constructing module Crabs...
# [15:52:55 INFO]: Constructing module Crafter...
# [15:52:55 INFO]: Constructing module Crate...
# [15:52:55 INFO]: Constructing module Diamond Repair...
# [15:52:55 INFO]: Constructing module Dispensers Place Blocks...
# [15:52:55 INFO]: Constructing module Double Door Opening...
# [15:52:55 INFO]: Constructing module Dragon Scales...
# [15:52:55 INFO]: Constructing module Duskbound Blocks...
# [15:52:55 INFO]: Constructing module Dyeable Item Frames...
# [15:52:55 INFO]: Constructing module Easy Transfering...
# [15:52:55 INFO]: Constructing module Elytra Indicator...
# [15:52:55 INFO]: Constructing module Emotes...
# [15:52:55 INFO]: Constructing module Enchantment Predicates...
# [15:52:55 INFO]: Constructing module Enchantments Begone...
# [15:52:55 INFO]: Constructing module Ender Watcher...
# [15:52:55 INFO]: Constructing module Endermosh Music Disc...
# [15:52:55 INFO]: Constructing module Enhanced Ladders...
# [15:52:55 INFO]: Constructing module Expanded Item Interactions...
# [15:52:55 INFO]: Constructing module Fairy Rings...
# [15:52:55 INFO]: Constructing module Feeding Trough...
# [15:52:55 INFO]: Constructing module Forgotten...
# [15:52:55 INFO]: Constructing module Foxhound...
# [15:52:55 INFO]: Constructing module Framed Glass...
# [15:52:55 INFO]: Constructing module Game Nerfs...
# [15:52:55 INFO]: Constructing module Glass Item Frame...
# [15:52:55 INFO]: Constructing module Glass Shard...
# [15:52:55 INFO]: Constructing module Glimmering Weald...
# [15:52:55 INFO]: Constructing module Gold Bars...
# [15:52:55 INFO]: Constructing module Gold Tools Have Fortune...
# [15:52:55 INFO]: Constructing module Grab Chickens...
# [15:52:55 INFO]: Constructing module Grate...
# [15:52:55 INFO]: Constructing module Gravisand...
# [15:52:55 INFO]: Constructing module Greener Grass...
# [15:52:55 INFO]: Constructing module Hedges...
# [15:52:55 INFO]: Constructing module Hoe Harvesting...
# [15:52:55 INFO]: Constructing module Hollow Logs...
# [15:52:55 INFO]: Constructing module Horses Swim...
# [15:52:55 INFO]: Constructing module Hotbar Changer...
# [15:52:55 INFO]: Constructing module Improved Sponges...
# [15:52:55 INFO]: Constructing module Improved Tooltips...
# [15:52:55 INFO]: Constructing module Industrial Palette...
# [15:52:55 INFO]: Constructing module Inventory Sorting...
# [15:52:55 INFO]: Constructing module Iron Rod...
# [15:52:55 INFO]: Constructing module Item Sharing...
# [15:52:55 INFO]: Constructing module Japanese Palette...
# [15:52:55 INFO]: Constructing module Leaf Carpet...
# [15:52:55 INFO]: Constructing module Lock Rotation...
# [15:52:55 INFO]: Constructing module Long Range Pick Block...
# [15:52:55 INFO]: Constructing module Magnets...
# [15:52:55 INFO]: Constructing module Map Washing...
# [15:52:55 INFO]: Constructing module Matrix Enchanting...
# [15:52:55 INFO]: Constructing module Metal Buttons...
# [15:52:55 INFO]: Constructing module Microcrafting Helper...
# [15:52:55 INFO]: Constructing module Midori...
# [15:52:55 INFO]: Constructing module Monster Box...
# [15:52:55 INFO]: Constructing module More Banner Layers...
# [15:52:55 INFO]: Constructing module More Brick Types...
# [15:52:55 INFO]: Constructing module More Mud Blocks...
# [15:52:55 INFO]: Constructing module More Note Block Sounds...
# [15:52:55 INFO]: Constructing module More Potted Plants...
# [15:52:55 INFO]: Constructing module Narrator Readout...
# [15:52:55 INFO]: Constructing module Nether Brick Fence Gate...
# [15:52:55 INFO]: Constructing module Nether Obsidian Spikes...
# [15:52:55 INFO]: Constructing module New Stone Types...
# [15:52:55 INFO]: Constructing module No Durability On Cosmetics...
# [15:52:55 INFO]: Constructing module No More Lava Pockets...
# [15:52:55 INFO]: Constructing module Obsidian Plate...
# [15:52:55 INFO]: Constructing module Overlay Shader...
# [15:52:55 INFO]: Constructing module Parrot Eggs...
# [15:52:55 INFO]: Constructing module Pat The Dogs...
# [15:52:55 INFO]: Constructing module Pathfinder Maps...
# [15:52:55 INFO]: Constructing module Permafrost...
# [15:52:55 INFO]: Constructing module Pickarang...
# [15:52:55 INFO]: Constructing module Pig Litters...
# [15:52:55 INFO]: Constructing module Pipes...
# [15:52:55 INFO]: Constructing module Pistons Move Tile Entities...
# [15:52:55 INFO]: Constructing module Poison Potato Usage...
# [15:52:55 INFO]: Constructing module Quick Armor Swapping...
# [15:52:55 INFO]: Constructing module Rainbow Lamps...
# [15:52:55 INFO]: Constructing module Raw Metal Bricks...
# [15:52:55 INFO]: Constructing module Reacharound Placing...
# [15:52:55 INFO]: Constructing module Redstone Randomizer...
# [15:52:55 INFO]: Constructing module Renewable Spore Blossoms...
# [15:52:55 INFO]: Constructing module Replace Scaffolding...
# [15:52:55 INFO]: Constructing module Rope...
# [15:52:55 INFO]: Constructing module Safer Creatures...
# [15:52:55 INFO]: Constructing module Seed Pouch...
# [15:52:55 INFO]: Constructing module Shear Vines...
# [15:52:55 INFO]: Constructing module Shiba...
# [15:52:55 INFO]: Constructing module Shingles...
# [15:52:55 INFO]: Constructing module Shulker Packing...
# [15:52:55 INFO]: Constructing module Simple Harvest...
# [15:52:55 INFO]: Constructing module Skull Pikes...
# [15:52:55 INFO]: Constructing module Slabs To Blocks...
# [15:52:55 INFO]: Constructing module Slime In A Bucket...
# [15:52:55 INFO]: Constructing module Slimes To Magma Cubes...
# [15:52:55 INFO]: Constructing module Snow Golem Player Heads...
# [15:52:55 INFO]: Constructing module Soul Candles...
# [15:52:55 INFO]: Constructing module Soul Sandstone...
# [15:52:55 INFO]: Constructing module Spawner Replacer...
# [15:52:55 INFO]: Constructing module Spiral Spires...
# [15:52:55 INFO]: Constructing module Stonelings...
# [15:52:55 INFO]: Constructing module Stools...
# [15:52:55 INFO]: Constructing module Sturdy Stone...
# [15:52:55 INFO]: Constructing module Thatch...
# [15:52:55 INFO]: Constructing module Tiny Potato...
# [15:52:55 INFO]: Constructing module Torch Arrow...
# [15:52:55 INFO]: Constructing module Toretoise...
# [15:52:55 INFO]: Constructing module Totem Of Holding...
# [15:52:55 INFO]: Constructing module Trowel...
# [15:52:55 INFO]: Constructing module Usage Ticker...
# [15:52:55 INFO]: Constructing module Uses For Curses...
# [15:52:55 INFO]: Constructing module Utility Recipes...
# [15:52:55 INFO]: Constructing module Variant Animal Textures...
# [15:52:55 INFO]: Constructing module Variant Bookshelves...
# [15:52:55 INFO]: Constructing module Variant Chests...
# [15:52:55 INFO]: Constructing module Variant Furnaces...
# [15:52:55 INFO]: Constructing module Variant Ladders...
# [15:52:55 INFO]: Constructing module Variant Selector...
# [15:52:55 INFO]: Constructing module Vertical Planks...
# [15:52:55 INFO]: Constructing module Vertical Slabs...
# [15:52:55 INFO]: Constructing module Vexes Die With Their Masters...
# [15:52:55 INFO]: Constructing module Villager Rerolling Rework...
# [15:52:55 INFO]: Constructing module Villagers Follow Emeralds...
# [15:52:55 INFO]: Constructing module Wooden Posts...
# [15:52:55 INFO]: Constructing module Wool Shuts Up Minecarts...
# [15:52:55 INFO]: Constructing module Wraith...
# [15:52:55 INFO]: Constructing module Zombie Villagers On Normal...
# [15:52:55 INFO]: Constructing module More Stone Variants...
# [15:52:55 INFO]: Constructed 160 modules.
# [15:52:56 INFO]: Dispatching ZRegister to 3 listeners
# [15:52:56 INFO]: Dispatching ZRegister$Post to 1 listener
# [15:52:56 INFO]: Dispatching ZRegister to 96 listeners
# [15:52:59 INFO]: Dispatching ZRegister$Post to 6 listeners
# [15:53:01 INFO]: Dispatching ForgeZEntityAttributeCreation (as ZEntityAttributeCreation) to 7 listeners
# [15:53:02 INFO]: Dispatching ZConfigChanged to 2 listeners
# [15:53:02 INFO]: 'zeta' is enabling Zeta's piston structure resolver.
# [15:53:02 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 2 listeners
# [15:53:02 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 40 listeners
# [15:53:02 INFO]: Dispatching ZConfigChanged to 2 listeners
# [15:53:02 INFO]: Loading Xaero's Minimap - Stage 1/2 (Server)
# [15:53:02 INFO]: Loading Xaero's World Map - Stage 1/2 (Server)
# [15:53:02 INFO]: Loading Xaero's Minimap - Stage 2/2 (Server)
# [15:53:02 INFO]: Loading Xaero's World Map - Stage 2/2 (Server)
# [15:53:02 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 6 listeners
# [15:53:02 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 1 listener
# [15:53:02 INFO]: Start loading plugin at snownee.jade.addon.vanilla.VanillaPlugin
# [15:53:02 INFO]: Start loading plugin at snownee.jade.addon.universal.UniversalPlugin
# [15:53:02 INFO]: Start loading plugin at snownee.jade.addon.core.CorePlugin
# [15:53:02 INFO]: Start loading plugin at net.geforcemods.securitycraft.compat.waila.JadeDataProvider
# [15:53:02 INFO]: Start loading plugin at ovh.corail.tombstone.compatibility.IntegrationJade
# [15:53:07 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [15:53:12 ERROR]: Cristel Lib Config Pack has no data
# [15:53:12 ERROR]: T&T Waystone Patch Pack condition is false, skipping
# [15:53:13 INFO]: Adding datapack listener capsid_recipes
# [15:53:13 INFO]: Dispatching ForgeZAddReloadListener (as ZAddReloadListener) to 2 listeners
# [15:53:13 INFO]: Dispatching ForgeZAddReloadListener (as ZAddReloadListener) to 2 listeners
# [15:53:13 WARN]: Tag entries for curios:tags/items/magic_book.json cleared by tombstone-1.20.1-8.6.3.jar
# [15:53:13 INFO]: Loaded 8 recipes
# [15:53:14 INFO]: Loaded 2542 advancements
# [15:53:14 INFO]: Loaded 13 curio slots
# [15:53:14 INFO]: Loaded 1 curio entities
# [15:53:14 INFO]: Modified advancement minecraft:husbandry/wax_on with 2 patches
# [15:53:14 INFO]: Modified advancement minecraft:adventure/kill_a_mob with 3 patches
# [15:53:14 INFO]: Modified advancement minecraft:husbandry/bred_all_animals with 3 patches
# [15:53:14 INFO]: Modified advancement minecraft:adventure/kill_all_mobs with 3 patches
# [15:53:14 INFO]: Modified advancement minecraft:husbandry/balanced_diet with 2 patches
# [15:53:14 INFO]: Modified advancement minecraft:nether/all_effects with 1 patches
# [15:53:14 INFO]: Modified advancement minecraft:husbandry/wax_off with 2 patches
# [15:53:14 INFO]: Modified advancement minecraft:adventure/adventuring_time with 1 patches
# [15:53:14 INFO]: Modified advancement minecraft:nether/all_potions with 1 patches
# [15:53:17 INFO]: Dispatching ZTagsUpdated to 1 listener
# [15:53:17 INFO]: Starting minecraft server version 1.20.1
# [15:53:17 INFO]: Loading properties
# [15:53:17 INFO]: Default game type: SURVIVAL
# [15:53:17 INFO]: Generating keypair
# [15:53:18 INFO]: Starting Minecraft server on *:25565
# [15:53:18 INFO]: Using epoll channel type
# [15:53:18 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [15:53:18 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [15:53:18 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [15:53:18 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [15:53:18 INFO]: This server is running Mohist version 1.20.1-580 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.20, NeoForge version 47.1.79)
# [15:53:19 INFO]: Debug logging is enabled
# [15:53:19 INFO]: Server Ping Player Sample Count: 20
# [15:53:19 INFO]: Using 4 threads for Netty based IO
# [15:53:19 INFO]: Hello Plugins!
# [15:53:19 INFO]: THe OkZoomer server config has been changed!
# [15:53:19 INFO]: THe OkZoomer server config has been changed!
# [15:53:19 INFO]: Preparing level "world"
# [15:53:24 INFO]: Preparing start region for dimension minecraft:overworld
# [15:53:28 INFO]: Preparing spawn area: 0%
# [15:53:28 INFO]: Preparing spawn area: 0%
# [15:53:28 INFO]: Preparing spawn area: 0%
# [15:53:28 INFO]: Preparing spawn area: 0%
# [15:53:28 INFO]: Preparing spawn area: 0%
# [15:53:28 INFO]: Preparing spawn area: 0%
# [15:53:28 INFO]: Preparing spawn area: 0%
# [15:53:28 INFO]: Preparing spawn area: 0%
# [15:53:28 INFO]: Preparing spawn area: 0%
# [15:53:29 INFO]: Preparing spawn area: 31%
# [15:53:29 INFO]: Time elapsed: 4966 ms
# [15:53:29 INFO]: Preparing start region for dimension minecraft:the_end
# [15:53:30 INFO]: Preparing spawn area: 0%
# [15:53:30 INFO]: Preparing spawn area: 0%
# [15:53:30 INFO]: Preparing spawn area: 0%
# [15:53:31 INFO]: Preparing spawn area: 0%
# [15:53:31 INFO]: Preparing spawn area: 94%
# [15:53:31 INFO]: Time elapsed: 2019 ms
# [15:53:31 INFO]: Preparing start region for dimension minecraft:the_nether
# [15:53:33 INFO]: Preparing spawn area: 0%
# [15:53:33 INFO]: Preparing spawn area: 0%
# [15:53:33 INFO]: Preparing spawn area: 0%
# [15:53:33 INFO]: Preparing spawn area: 0%
# [15:53:33 INFO]: Preparing spawn area: 17%
# [15:53:33 INFO]: Time elapsed: 2339 ms
# [15:53:34 INFO]: [Mohist] Enabling Mohist v1.20.1
# [15:53:34 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [15:53:34 INFO]: Done (14.947s)! For help, type "help"
# [15:53:34 INFO]: Successfully initialized permission handler forge:default_handler
# [15:53:34 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [15:57:33 INFO]: varon1306 joined the game
# [15:57:33 INFO]: Syncing config to varon1306 (ac8e9d20-c3b3-3639-aaed-9845602386a9)
# [15:57:33 INFO]: varon1306[/127.0.0.1:49362] logged in with entity id 530 at ([world]-6293.38321771454, 110.0, 9949.408532286812)
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [16:20:38 INFO]: varon1306 has made the advancement [advancements.alexsmobs.rattlesnake.title]
# [16:22:35 ERROR]: Hanging entity at invalid position: BlockPos{x=-318, y=-45, z=-204}
# [16:22:35 ERROR]: Hanging entity at invalid position: BlockPos{x=-320, y=-45, z=-203}
# [16:22:35 ERROR]: Hanging entity at invalid position: BlockPos{x=-318, y=-45, z=-202}
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [16:24:38 ERROR]: No key selector in MapLike[{event_delay:0,event_distance:0.0f,range:16,source:{source_entity:[I;1154287141,-1131000828,-1722453399,506254198],type:"minecraft:entity",y_offset:0.36f}}]
# [16:28:35 WARN]: Skipping Entity with id
# [16:28:45 WARN]: Skipping Entity with id
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [16:37:49 ERROR]: Hanging entity at invalid position: BlockPos{x=-16, y=-54, z=1646}
# [16:37:55 WARN]: Skipping Entity with id
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [16:44:17 INFO]: varon1306 has made the advancement [advancement.dungeons_arise.find_lighthouse.title]
# [16:46:01 WARN]: UUID of added entity already exists: Drowned['Drowned'/22271, l='ServerLevel[world]', x=-4111.50, y=37.00, z=9393.50]
# [16:46:04 WARN]: UUID of added entity already exists: Drowned['Drowned'/22316, l='ServerLevel[world]', x=-4111.50, y=36.00, z=9391.50]
# [16:46:06 ERROR]: Hanging entity at invalid position: BlockPos{x=-49, y=-56, z=187}
# [16:46:06 ERROR]: Hanging entity at invalid position: BlockPos{x=-49, y=-56, z=189}
# [16:46:06 ERROR]: Hanging entity at invalid position: BlockPos{x=-48, y=-56, z=186}
# [16:46:06 ERROR]: Hanging entity at invalid position: BlockPos{x=-45, y=-56, z=187}
# [16:46:06 ERROR]: Hanging entity at invalid position: BlockPos{x=-46, y=-56, z=186}
# [16:46:06 ERROR]: Hanging entity at invalid position: BlockPos{x=-48, y=-56, z=190}
# [16:46:06 ERROR]: Hanging entity at invalid position: BlockPos{x=-46, y=-56, z=190}
# [16:46:06 ERROR]: Hanging entity at invalid position: BlockPos{x=-45, y=-56, z=189}
# [16:46:10 ERROR]: Hanging entity at invalid position: BlockPos{x=-21, y=-51, z=186}
# [16:46:10 ERROR]: No key selector in MapLike[{event_delay:0,event_distance:0.0f,range:16,source:{source_entity:[I;176865803,-972338229,-2060744252,-623071664],type:"minecraft:entity",y_offset:0.36f}}]
# [16:46:10 ERROR]: No key selector in MapLike[{event_delay:0,event_distance:0.0f,range:16,source:{source_entity:[I;672061792,-366263352,-1752079043,-405291646],type:"minecraft:entity",y_offset:0.36f}}]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [17:08:46 INFO]: com.mojang.authlib.GameProfile@1cb46cef[id=56c8d8c6-acde-3bbd-882f-3d397f6aab3c,name=JuacoT,properties={},legacy=false] (/127.0.0.1:48010) lost connection: Disconnected
# [17:09:00 INFO]: JuacoT joined the game
# [17:09:00 INFO]: Syncing config to JuacoT (56c8d8c6-acde-3bbd-882f-3d397f6aab3c)
# [17:09:00 INFO]: JuacoT[/127.0.0.1:38324] logged in with entity id 32179 at ([world]-6238.783024200675, -47.0, 9961.481623975931)
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [17:12:43 INFO]: playerrevive.chat.bleeding
# [17:12:43 WARN]: The death event of the player varon1306 was canceled by another mod
# [17:12:43 INFO]: tombstone.message.recovery.save_player.success
# [17:12:49 INFO]: varon1306 was obliterated by a sonically-charged shriek
# [17:19:39 INFO]: JuacoT issued server command: /tp varon1306 @s
# >
